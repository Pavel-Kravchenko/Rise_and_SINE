# %% [markdown]
# # Generating figure 1.2

# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson
import seaborn as sns
import pybedtools as pbt
from collections import Counter
import random
from random import Random
from math import ldexp
import json
from collections import Counter
from scipy.stats import poisson
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing TFs data

# %%
def import_TF_bed(path, sep=";", header=0):
    df=pd.read_csv(path, sep=sep, header = header)
    df.columns = [x for x in range(df.shape[1])]
    df["middle"] = df[1] + (df[2] - df[1])//2
    df[1] = df["middle"]
    df[2] = df["middle"]
    df = df.drop(["middle"], axis=1)
    df = df[[0,1,2]]
    return df

Nr5a2 = import_TF_bed('./tables/science.abn7478_table_s10.csv')
# Obox data were converted from mm9 to mm10 with https://genome.ucsc.edu/cgi-bin/hgLiftOver
Obox1 = import_TF_bed('./tables/hglft_genome_7e52_b4b220.bed', sep="\t")
Obox5 = import_TF_bed('./tables/hglft_genome_8f25_b4b8c0.bed', sep="\t")
Obox3 = import_TF_bed('./tables/hglft_genome_9296_b4baa0.bed', sep="\t")
Obox15 = pbt.BedTool.intersect(pbt.BedTool.from_dataframe(Obox1), pbt.BedTool.from_dataframe(Obox5), c=True).to_dataframe()
Obox15 = Obox15[["chrom","start","end"]]

Dux_rep1 = import_TF_bed('./tables/rep1_41588_2017_BFng3844_MOESM322_ESM.csv')
Dux_rep2 = import_TF_bed('./tables/rep2_41588_2017_BFng3844_MOESM322_ESM.csv')
Dux = pbt.BedTool.intersect(pbt.BedTool.from_dataframe(Dux_rep1), pbt.BedTool.from_dataframe(Dux_rep2), c=True).to_dataframe()
Dux = Dux[["chrom","start","end"]]


TF1 = Nr5a2
TF2 = Obox3

TF1n = "Nr5a2"
TF2n = "Obox3"

# %%
Nr5a2.to_csv('./tables/Nr5a2_peaks.bed', sep=" ", header=None, index=False)
Obox3.to_csv('./tables/Obox3_peaks.bed', sep=" ", header=None, index=False)
Dux.to_csv('./tables/Dux_peaks.bed', sep=" ", header=None, index=False)

# %%
df = pbt.BedTool.from_dataframe(Nr5a2).sort().closest(pbt.BedTool.from_dataframe(Dux).sort(), t="all", D="a").to_dataframe(disable_auto_names=True, header=None)
df = df[abs(df[6]) < 1000]
mu = 1
rv = poisson(mu)

df["Distance"] = abs(df[6])
df["-log10 Poisson P-value"] = -1*np.log10(np.array([rv.pmf(x) for x in df["Distance"]]))

sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
matplotlib.rcParams['font.weight'] = "medium"
matplotlib.rcParams['axes.labelweight'] = 'medium'
matplotlib.rcParams['figure.titleweight'] = 'medium'
matplotlib.rcParams['axes.titleweight'] = 'medium'
matplotlib.rcParams['figure.figsize'] = 20, 10
ax = sns.histplot(data=df, x="Distance", bins=50, kde=True, element="step")
ax.set(xlabel='Distance', ylabel='Number of colocalized peaks')
plt.title(f"Distance betwen Nr5a2 - Dux peaks", y=1.01)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/834373980.py:7: RuntimeWarning: divide by zero encountered in log10
#   df["-log10 Poisson P-value"] = -1*np.log10(np.array([rv.pmf(x) for x in df["Distance"]]))

# %%
df = pbt.BedTool.from_dataframe(Nr5a2).sort().closest(pbt.BedTool.from_dataframe(Obox3).sort(), t="all", D="a").to_dataframe(disable_auto_names=True, header=None)
df = df[abs(df[6]) < 1000]
mu = 1
rv = poisson(mu)

df["Distance"] = abs(df[6])
df["-log10 Poisson P-value"] = -1*np.log10(np.array([rv.pmf(x) for x in df["Distance"]]))

sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
matplotlib.rcParams['font.weight'] = "medium"
matplotlib.rcParams['axes.labelweight'] = 'medium'
matplotlib.rcParams['figure.titleweight'] = 'medium'
matplotlib.rcParams['axes.titleweight'] = 'medium'
matplotlib.rcParams['figure.figsize'] = 20, 10
ax = sns.histplot(data=df, x="Distance", bins=50, kde=True, element="step")
ax.set(xlabel='Distance', ylabel='Number of colocalized peaks')
plt.title(f"Distance betwen Nr5a2 - Obox3 peaks", y=1.01)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/1276192122.py:7: RuntimeWarning: divide by zero encountered in log10
#   df["-log10 Poisson P-value"] = -1*np.log10(np.array([rv.pmf(x) for x in df["Distance"]]))

# %%
df = pbt.BedTool.from_dataframe(Obox3).sort().closest(pbt.BedTool.from_dataframe(Dux).sort(), t="all", D="a").to_dataframe(disable_auto_names=True, header=None)
df = df[abs(df[6]) < 1000]
mu = 1
rv = poisson(mu)

df["Distance"] = abs(df[6])
df["-log10 Poisson P-value"] = -1*np.log10(np.array([rv.pmf(x) for x in df["Distance"]]))

sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
matplotlib.rcParams['font.weight'] = "medium"
matplotlib.rcParams['axes.labelweight'] = 'medium'
matplotlib.rcParams['figure.titleweight'] = 'medium'
matplotlib.rcParams['axes.titleweight'] = 'medium'
matplotlib.rcParams['figure.figsize'] = 20, 10
ax = sns.histplot(data=df, x="Distance", bins=50, kde=True, element="step")
ax.set(xlabel='Distance', ylabel='Number of colocalized peaks')
plt.title(f"Distance betwen Obox3 - Dux peaks", y=1.01)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/2517709951.py:7: RuntimeWarning: divide by zero encountered in log10
#   df["-log10 Poisson P-value"] = -1*np.log10(np.array([rv.pmf(x) for x in df["Distance"]]))

# %% [markdown]
# ## A toy example

# %%
dfa = pd.DataFrame({0:["chr1","chr1","chr1"], 1:[1,2,9], 2:[4,5,9]})

dfb = pd.DataFrame({0:["chr1","chr1","chr1"], 1:[1,2,3], 2:[1,5,6]})

pbtdf1 = pbt.BedTool.from_dataframe(dfa)
pbtdf2 = pbt.BedTool.from_dataframe(dfb)
pbtdf1.closest(pbtdf2, t="all", D="a").to_dataframe(disable_auto_names=True, header=None)
# Out:
#       0  1  2     3  4  5  6
# 0  chr1  1  4  chr1  1  1  0
# 1  chr1  1  4  chr1  2  5  0
# 2  chr1  1  4  chr1  3  6  0
# 3  chr1  2  5  chr1  2  5  0
# 4  chr1  2  5  chr1  3  6  0
# 5  chr1  9  9  chr1  3  6 -3

# %% [markdown]
# ## Generating a simulated distribution

# %%
class FullRandom(Random):
    # From https://docs.python.org/3/library/random.html
    def random(self):
        mantissa = 0x10_0000_0000_0000 | self.getrandbits(52)
        exponent = -53
        x = 0
        while not x:
            x = self.getrandbits(32)
            exponent += x.bit_length() - 32
        return ldexp(mantissa, exponent)

fr = FullRandom() 
pbtdf1 = pbt.BedTool.from_dataframe(TF1).sort()
pbtdf2 = pbt.BedTool.from_dataframe(TF2).sort()
collector_list = []
N=1000
for i in range(N): # Memory intensive with hight N
    if i%100 == 0:
        print(i)
    pbtdf1 = pbtdf1.shuffle(genome='mm10', chrom=True, seed=round(fr.random()*10**5, 4)).sort()
    pbtdf2 = pbtdf2.shuffle(genome='mm10', chrom=True, seed=round(fr.random()*10**5, 4)).sort()
    closest_df = pbtdf1.closest(pbtdf2, t="all", D="a").to_dataframe(disable_auto_names=True, header=None)
    collector_list.append(Counter(abs(closest_df[6])))  
    
# with open(f'simulated_distances_{TF1n}_{TF2n}.json', 'w') as fp:
#     json.dump(collector_list, fp)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
def recalculare_dict(df_tmp):
    df_tmp_out = pd.DataFrame({"Keys":df_tmp.keys(), "Values":df_tmp.values()})
    return df_tmp_out


simulated_distances_df = pd.DataFrame()
for df_tmp in collector_list:
    simulated_distances_df=pd.concat([simulated_distances_df, recalculare_dict(df_tmp)])
    
simulated_distances_df["Keys"] = [int(x) for x in simulated_distances_df["Keys"]]
df_sorted = simulated_distances_df.sort_values("Keys", ascending=True)

simulated_distances_df_sorted_grouped = df_sorted.groupby('Keys', as_index=False).agg(Values_sum = ('Values', sum),
                                                  Values_mean = ('Values', np.mean),
                                                  Values_median = ('Values', np.median),
                                                  Values_std = ('Values', np.std))

# %% [raw]
# import json
# os.chdir("/Users/pavel/Desktop/MPIB/Python_scripts")
#
# with open(f'simulated_distances_{TF1n}_{TF2n}.json', 'r') as fp:
#     collector_list = json.load(fp)
#
# with open(f'simulated_distances_{TF1n}_{TF2n}_dict.json', 'r') as fp:
#     simulated_distances_dict = json.load(fp)

# %% [markdown]
# ## Comparing simulation to the real data

# %%
def caclulate_poisson(df):
    
    df["distance"] = abs(df[6])
    Counter_df = Counter(df["distance"])
    d_compare = {}

    for i in list(Counter_df.keys()):
        if i not in list(d_compare.keys()):
            d_compare[i] = Counter_df[i]
        else:
            d_compare[i] = d_compare[i] + Counter_df[i]

    df_tmp = pd.DataFrame({"Keys":d_compare.keys(), "Values":d_compare.values()})
    df_tmp = df_tmp.sort_values("Keys", ascending=True)
    df_tmp = df_tmp[df_tmp["Keys"] < 1000]
    df_tmp["-log10 Poisson P-value"] = -1 * np.array([poisson(list(simulated_distances_df_sorted_grouped[x == simulated_distances_df_sorted_grouped["Keys"]]["Values_mean"])[0]).logpmf(d_compare[x]) if x in simulated_distances_df_sorted_grouped["Keys"] else 0 for x in df_tmp["Keys"]])
    df_tmp = df_tmp.reset_index(drop=True)

    df_poisson = []
    pval = [int(x) for x in np.array(df_tmp["-log10 Poisson P-value"])]
    for i in range(df_tmp.shape[0]):
        key_list_i = list(df_tmp["Keys"])[i]
        for j in range(pval[i]):
            df_poisson.append(key_list_i)

    return df_poisson

# %%
df_real = pbt.BedTool.from_dataframe(TF1).sort().closest(pbt.BedTool.from_dataframe(TF2).sort(), t="all", D="a").to_dataframe(disable_auto_names=True, header=None)
df_shuffle = pbt.BedTool.from_dataframe(TF1).sort().closest(pbt.BedTool.from_dataframe(TF2).sort().shuffle(genome='mm10', chrom=True).sort(), t="all", D="a").to_dataframe(disable_auto_names=True, header=None)

df_poisson_real = caclulate_poisson(df_real)
df_poisson_shuffle = caclulate_poisson(df_shuffle)

# %%
df_poisson_h_all = df_poisson_real + df_poisson_shuffle
df_poisson_h_alln = [f"{TF1n}/{TF2n}"]*len(df_poisson_real) + ["Control"] * len(df_poisson_shuffle)

# %%
sns.set_theme(style="whitegrid",font_scale=3)
sns.set_style("white")
matplotlib.rcParams['font.weight'] = "medium"
matplotlib.rcParams['axes.labelweight'] = 'medium'
matplotlib.rcParams['figure.titleweight'] = 'medium'
matplotlib.rcParams['axes.titleweight'] = 'medium'
matplotlib.rcParams['figure.figsize'] = 10, 10

dfff = pd.DataFrame({"x":df_poisson_h_all, "Peaks category":df_poisson_h_alln})
dfff = dfff[dfff["x"] < 1000]

ax = sns.histplot(data=dfff, x="x", hue="Peaks category", bins=20, kde=True, element="step", palette=["gray", "black"])
ax.set(xlabel='Distance (bp)', ylabel='-log10 Poisson P-value')
plt.title(f"Distance betwen \n {TF1n} - {TF2n} peaks ", fontsize=30, y=1.01)
plt.tight_layout()
out_pdf = f"./figures/{TF1n}_peak_{TF2n}_peak.pdf"
plt.savefig(out_pdf)
plt.show()

# %% [raw]
# ! wget https://hgdownload.soe.ucsc.edu/goldenPath/mm10/database/rmsk.txt.gz
# ! gzip -d rmsk.txt.gz
# ! mv rmsk.txt mm10_repeatmasker.csv

# %%
# Importing mm10_repeatmasker table
mm10_repeatmasker = pd.read_csv('./mm10_repeatmasker.csv',sep="\t")
mm10_repeatmasker.columns = ['#bin', 'swScore', 'milliDiv', 'milliDel', 'milliIns', 'genoName',
       'genoStart', 'genoEnd', 'genoLeft', 'strand', 'repName', 'repClass',
       'repFamily', 'repStart', 'repEnd', 'repLeft', 'id']
mm10_repeatmasker = mm10_repeatmasker[["genoName","genoStart","genoEnd","strand","repName","repClass","repFamily"]].dropna()
mm10_repeatmasker = mm10_repeatmasker[[True if len(chromosome)<6 else False for chromosome in list(mm10_repeatmasker["genoName"])]]
mm10_repeatmasker = mm10_repeatmasker[mm10_repeatmasker["repFamily"] == "Alu"]

# %%
mm10_repeatmasker[mm10_repeatmasker["repFamily"] == "Alu"].to_csv('./tables/mm10_repeatmasker.bed', sep=" ", header=None, index=False)

# %%
def caclulate_poisson_p(df):
    
    df["distance"] = abs(df[6])
    Counter_df = Counter(df["distance"])
    d_compare = {}

    for i in list(Counter_df.keys()):
        if i not in list(d_compare.keys()):
            d_compare[i] = Counter_df[i]
        else:
            d_compare[i] = d_compare[i] + Counter_df[i]

    df_tmp = pd.DataFrame({"Keys":d_compare.keys(), "Values":d_compare.values()})
    df_tmp = df_tmp.sort_values("Keys", ascending=True)
    df_tmp = df_tmp[df_tmp["Keys"] < 1000]
    df_tmp["-log10 Poisson P-value"] = -1 * np.array([poisson(list(simulated_distances_df_sorted_grouped[x == simulated_distances_df_sorted_grouped["Keys"]]["Values_mean"])[0]).logpmf(d_compare[x]) if x in simulated_distances_df_sorted_grouped["Keys"] else 0 for x in df_tmp["Keys"]])
    df_tmp = df_tmp.reset_index(drop=True)

    return df_tmp

# %%
# Calculating overlap and number of RE
df_poisson = pbt.BedTool.from_dataframe(TF1).sort().closest(pbt.BedTool.from_dataframe(TF2).sort(), t="all", D="a").to_dataframe(disable_auto_names=True, header=None)

df_poisson["distance"] = abs(df_poisson[6])
df_closest = df_poisson[(df_poisson["distance"] < 100)]
df_closest = df_closest[[0,1,2]]

pbt_df_rep = pbt.BedTool.from_dataframe(mm10_repeatmasker)
pbt_df_peaks = pbt.BedTool.from_dataframe(df_closest)
pbt_df_int = pbt.BedTool.intersect(pbt_df_peaks, pbt_df_rep, wb=True, v=False)

pbt_df_int = pbt_df_int.to_dataframe()
pbt_df_int = pbt_df_int.drop_duplicates()
rep_count = pbt_df_int.groupby(['blockCount']).size().reset_index(name='counts').sort_values("counts", ascending=False)
rep_count["counts_norm"] = rep_count["counts"]/df_closest.shape[0]*100

# %%
df_poisson = pbt.BedTool.from_dataframe(TF1).sort().closest(pbt.BedTool.from_dataframe(TF2).sort(), t="all", D="a").to_dataframe(disable_auto_names=True, header=None)

df_poisson["distance"] = abs(df_poisson[6])
df_closest = df_poisson[(df_poisson["distance"] < 200)]
#df_closest_bkp = df_closest.copy()
#df_closest = df_closest[[0,1,2]]

pbt_df_rep = pbt.BedTool.from_dataframe(mm10_repeatmasker)
pbt_df_peaks = pbt.BedTool.from_dataframe(df_closest)

pbt_df_int = pbt.BedTool.intersect(pbt_df_peaks, pbt_df_rep, loj=True, v=False)

pbt_df_int = pbt_df_int.to_dataframe(names=[x for x in range(15)])
pbt_df_int = pbt_df_int.replace(".", None).dropna()

pbt_df_int = pbt_df_int[(pbt_df_int[9] < pbt_df_int[4]) & (pbt_df_int[4] < pbt_df_int[10])]
pbt_df_int

# %%
# Out:
#         0          1          2     3          4          5    6    7     8   \
# 3     chr1   13083965   13083965  chr1   13083889   13083889  -75   75  chr1
# 14    chr1   21327857   21327857  chr1   21327886   21327886   28   28  chr1
# 15    chr1   21354203   21354203  chr1   21354218   21354218   14   14  chr1
# 17    chr1   21372795   21372795  chr1   21372881   21372881   85   85  chr1
# 18    chr1   21378408   21378408  chr1   21378425   21378425   16   16  chr1
# ...    ...        ...        ...   ...        ...        ...  ...  ...   ...
# 3644  chrX  102254851  102254851  chrX  102254863  102254863   11   11  chrX
# 3645  chrX  103271132  103271132  chrX  103271171  103271171   38   38  chrX
# 3648  chrX  108845712  108845712  chrX  108845585  108845585 -126  126  chrX
# 3660  chrX  142420617  142420617  chrX  142420632  142420632   14   14  chrX
# 3662  chrX  151015198  151015198  chrX  151015212  151015212   13   13  chrX
#
#              9          10 11       12    13   14
# 3      13083851   13083988  -  B1_Mus2  SINE  Alu
# 14     21327831   21327978  +  B1_Mus2  SINE  Alu
# 15     21354134   21354278  -    B1_Mm  SINE  Alu
# 17     21372774   21372915  -    B1_Mm  SINE  Alu
# 18     21378388   21378467  +    PB1D9  SINE  Alu
# ...         ...        ... ..      ...   ...  ...
# 3644  102254750  102254897  -    B1_Mm  SINE  Alu
# 3645  103271062  103271212  +  B1_Mus2  SINE  Alu
# 3648  108845576  108845742  +  B1_Mus1  SINE  Alu
# 3660  142420581  142420714  +  B1_Mur3  SINE  Alu
# 3662  151015080  151015229  -  B1_Mus2  SINE  Alu
#
# [767 rows x 15 columns]

# %% [raw]
# pbt_df_int = pbt_df_int[[False if (pbt_df_int[6][i]<0) & (pbt_df_int[11][i]=="-") else False]
# pbt_df_int

# %%
pbt_df_int["coordinate.x"] = [x-y if i == "+" else z-x for x,y,z,i in zip(pbt_df_int[1], pbt_df_int[9], pbt_df_int[10], pbt_df_int[11])]
pbt_df_int["coordinate.y"] = [x-y if i == "+" else z-x for x,y,z,i in zip(pbt_df_int[4], pbt_df_int[9], pbt_df_int[10], pbt_df_int[11])]
pbt_df_int["coordinate.d"] = pbt_df_int["coordinate.x"] - pbt_df_int["coordinate.y"]
pbt_df_int
# Out:
#          0          1          2     3          4          5    6    7     8  \
# 3     chr1   13083965   13083965  chr1   13083889   13083889  -75   75  chr1
# 8     chr1   16650349   16650349  chr1   16650457   16650457  107  107  chr1
# 9     chr1   16683624   16683624  chr1   16683753   16683753  128  128  chr1
# 13    chr1   21308780   21308780  chr1   21308831   21308831   50   50  chr1
# 14    chr1   21327857   21327857  chr1   21327886   21327886   28   28  chr1
# ...    ...        ...        ...   ...        ...        ...  ...  ...   ...
# 3660  chrX  142420617  142420617  chrX  142420632  142420632   14   14  chrX
# 3662  chrX  151015198  151015198  chrX  151015212  151015212   13   13  chrX
# 3667  chrX  160958350  160958350  chrX  160958433  160958433   82   82  chrX
# 3668  chrX  162618383  162618383  chrX  162618314  162618314  -68   68  chrX
# 3674  chrX  162943369  162943369  chrX  162943520  162943520  150  150  chrX
#
#               9         10 11       12    13   14  coordinate.x  coordinate.y  \
# 3      13083851   13083988  -  B1_Mus2  SINE  Alu            23            99
# 8      16650235   16650371  -  B1_Mur4  SINE  Alu            22           -86
# 9      16683496   16683636  -  B1_Mur3  SINE  Alu            12          -117
# 13     21308674   21308809  -    B1_Mm  SINE  Alu            29           -22
# 14     21327831   21327978  +  B1_Mus2  SINE  Alu            26            55
# ...         ...        ... ..      ...   ...  ...           ...           ...
# 3660  142420581  142420714  +  B1_Mur3  SINE  Alu            36            51
# 3662  151015080  151015229  -  B1_Mus2  SINE  Alu            31            17
# 3667  160958265  160958412  +  B1_Mur3  SINE  Alu            85           168
# 3668  162618361  162618499  +  B1_Mus1  SINE  Alu            22           -47
# 3674  162943264  162943416  -  B1_Mus1  SINE  Alu            47          -104
#
#       coordinate.d
# 3              -76
# 8              108
# 9              129
# 13              51
# 14             -29
# ...            ...
# 3660           -15
# 3662            14
# 3667           -83
# 3668            69
# 3674           151
#
# [1787 rows x 18 columns]

# %%
pbt_df_int

# %%
pbt_df_int  = pbt_df_int[pbt_df_int[11] == "+"]
pbt_df_int
# Out:
#          0          1          2     3          4          5    6    7     8  \
# 14    chr1   21327857   21327857  chr1   21327886   21327886   28   28  chr1
# 18    chr1   21378408   21378408  chr1   21378425   21378425   16   16  chr1
# 22    chr1   30818066   30818066  chr1   30817896   30817896 -169  169  chr1
# 23    chr1   30906662   30906662  chr1   30906661   30906661    0    0  chr1
# 25    chr1   30956091   30956091  chr1   30956171   30956171   79   79  chr1
# ...    ...        ...        ...   ...        ...        ...  ...  ...   ...
# 3648  chrX  108845712  108845712  chrX  108845585  108845585 -126  126  chrX
# 3649  chrX  111506655  111506655  chrX  111506501  111506501 -153  153  chrX
# 3660  chrX  142420617  142420617  chrX  142420632  142420632   14   14  chrX
# 3667  chrX  160958350  160958350  chrX  160958433  160958433   82   82  chrX
# 3668  chrX  162618383  162618383  chrX  162618314  162618314  -68   68  chrX
#
#               9         10 11       12    13   14  coordinate.x  coordinate.y  \
# 14     21327831   21327978  +  B1_Mus2  SINE  Alu            26            55
# 18     21378388   21378467  +    PB1D9  SINE  Alu            20            37
# 22     30818061   30818208  +  B1_Mus2  SINE  Alu             5          -165
# 23     30906595   30906742  +  B1_Mus2  SINE  Alu            67            66
# 25     30956085   30956139  +    PB1D9  SINE  Alu             6            86
# ...         ...        ... ..      ...   ...  ...           ...           ...
# 3648  108845576  108845742  +  B1_Mus1  SINE  Alu           136             9
# 3649  111506610  111506751  +  B1_Mus1  SINE  Alu            45          -109
# 3660  142420581  142420714  +  B1_Mur3  SINE  Alu            36            51
# 3667  160958265  160958412  +  B1_Mur3  SINE  Alu            85           168
# 3668  162618361  162618499  +  B1_Mus1  SINE  Alu            22           -47
#
#       coordinate.d
# 14             -29
# 18             -17
# 22             170
# 23               1
# 25             -80
# ...            ...
# 3648           127
# 3649           154
# 3660           -15
# 3667           -83
# 3668            69
#
# [871 rows x 18 columns]

# %%
pbt_df_int["coordinate.y_s"] = pbt_df_int["coordinate.y"]*np.sign(pbt_df_int[6])
pbt_df_int
# Out:
#          0          1          2     3          4          5    6    7     8  \
# 1     chr1   13083965   13083965  chr1   13083889   13083889  -75   75  chr1
# 12    chr1   21327857   21327857  chr1   21327886   21327886   28   28  chr1
# 13    chr1   21354203   21354203  chr1   21354218   21354218   14   14  chr1
# 15    chr1   21372795   21372795  chr1   21372881   21372881   85   85  chr1
# 16    chr1   21378408   21378408  chr1   21378425   21378425   16   16  chr1
# ...    ...        ...        ...   ...        ...        ...  ...  ...   ...
# 3095  chrX  102254851  102254851  chrX  102254863  102254863   11   11  chrX
# 3096  chrX  103271132  103271132  chrX  103271171  103271171   38   38  chrX
# 3098  chrX  108845712  108845712  chrX  108845585  108845585 -126  126  chrX
# 3107  chrX  142420617  142420617  chrX  142420632  142420632   14   14  chrX
# 3109  chrX  151015198  151015198  chrX  151015212  151015212   13   13  chrX
#
#               9         10 11       12    13   14  coordinate.x  coordinate.y  \
# 1      13083851   13083988  -  B1_Mus2  SINE  Alu            23            99
# 12     21327831   21327978  +  B1_Mus2  SINE  Alu            26            55
# 13     21354134   21354278  -    B1_Mm  SINE  Alu            75            60
# 15     21372774   21372915  -    B1_Mm  SINE  Alu           120            34
# 16     21378388   21378467  +    PB1D9  SINE  Alu            20            37
# ...         ...        ... ..      ...   ...  ...           ...           ...
# 3095  102254750  102254897  -    B1_Mm  SINE  Alu            46            34
# 3096  103271062  103271212  +  B1_Mus2  SINE  Alu            70           109
# 3098  108845576  108845742  +  B1_Mus1  SINE  Alu           136             9
# 3107  142420581  142420714  +  B1_Mur3  SINE  Alu            36            51
# 3109  151015080  151015229  -  B1_Mus2  SINE  Alu            31            17
#
#       coordinate.d  coordinate.y_s
# 1              -76             -99
# 12             -29              55
# 13              15              60
# 15              86              34
# 16             -17              37
# ...            ...             ...
# 3095            12              34
# 3096           -39             109
# 3098           127              -9
# 3107           -15              51
# 3109            14              17
#
# [767 rows x 19 columns]

# %%
sns.distplot(pbt_df_int["coordinate.x"], color="gray")
# Out:
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/2342712312.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pbt_df_int["coordinate.x"], color="gray")
# <AxesSubplot: xlabel='coordinate.x', ylabel='Density'>
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.
# findfont: Font family 'Lato' not found.

# %%
sns.set(font_scale=2.1, style="ticks")
sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
matplotlib.rcParams['font.weight'] = "medium"
matplotlib.rcParams['axes.labelweight'] = 'medium'
matplotlib.rcParams['figure.titleweight'] = 'medium'
matplotlib.rcParams['axes.titleweight'] = 'medium'
matplotlib.rcParams['figure.figsize'] = 10, 5
sns.despine()


ax = sns.distplot(pbt_df_int["coordinate.x"], color="gray")
ax = sns.distplot(pbt_df_int["coordinate.y"], color="black")

ax.grid(False)
plt.setp(ax.artists, edgecolor = 'k', facecolor='w')
plt.setp(ax.lines, color='k')
sns.set(font_scale=2.5, style="ticks", font="Lato")
ax.set(ylabel='Density', xlabel="Coordinate from Alu start")
plt.title(f"Nr5a2 and Obox3 binding to SINE B1/Alu", y=1.01) 
#plt.xticks(rotation=90)

sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()
plt.savefig("./figures/Nr5a2_Obox_binding_to_Alu.pdf")
# Out:
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/4266162490.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(pbt_df_int["coordinate.x"], color="gray")
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/4266162490.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(pbt_df_int["coordinate.y"], color="black")

# %%
pbt_df_rep = pbt.BedTool.from_dataframe(mm10_repeatmasker)

pbt_df_int1 = pbt.BedTool.intersect(pbt.BedTool.from_dataframe(TF1).sort(), pbt_df_rep, loj=True, v=False)
pbt_df_int1 = pbt_df_int1.to_dataframe()
pbt_df_int1 = pbt_df_int1.replace(".", None).dropna()
pbt_df_int1



pbt_df_int2 = pbt.BedTool.intersect(pbt.BedTool.from_dataframe(TF2).sort(), pbt_df_rep, loj=True, v=False)
pbt_df_int2 = pbt_df_int2.to_dataframe()
pbt_df_int2 = pbt_df_int2.replace(".", None).dropna()
pbt_df_int2
# Out:
#       chrom      start        end  name      score     strand thickStart  \
# 3      chr1    4699888    4699888  chr1    4699866    4700013          +
# 5      chr1    4766414    4766414  chr1    4766380    4766527          +
# 8      chr1    4779309    4779309  chr1    4779170    4779317          -
# 10     chr1    4803020    4803020  chr1    4802944    4803091          -
# 13     chr1    4826530    4826530  chr1    4826522    4826668          -
# ...     ...        ...        ...   ...        ...        ...        ...
# 32100  chrX  164070398  164070398  chrX  164070281  164070428          +
# 32105  chrX  165061391  165061391  chrX  165061357  165061483          +
# 32109  chrX  166506225  166506225  chrX  166506127  166506258          +
# 32111  chrX  168667322  168667322  chrX  168667226  168667368          -
# 32117  chrX  169336190  169336190  chrX  169336061  169336206          -
#
#       thickEnd itemRgb blockCount
# 3        B1_Mm    SINE        Alu
# 5      B1_Mus2    SINE        Alu
# 8      B1_Mus2    SINE        Alu
# 10     B1_Mus2    SINE        Alu
# 13     B1_Mus2    SINE        Alu
# ...        ...     ...        ...
# 32100    B1_Mm    SINE        Alu
# 32105    B1_Mm    SINE        Alu
# 32109  B1_Mur3    SINE        Alu
# 32111  B1_Mur1    SINE        Alu
# 32117    B1_Mm    SINE        Alu
#
# [11409 rows x 10 columns]

# %%
pbt_df_int1["coordinate"] = [x-y if i == "+" else z-x for x,y,z,i in zip(pbt_df_int1["start"], pbt_df_int1["score"], pbt_df_int1["strand"], pbt_df_int1["thickStart"])]
pbt_df_int2["coordinate"] = [x-y if i == "+" else z-x for x,y,z,i in zip(pbt_df_int2["start"], pbt_df_int2["score"], pbt_df_int2["strand"], pbt_df_int2["thickStart"])]

# %%
sns.set(font_scale=2.1, style="ticks")
sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
matplotlib.rcParams['font.weight'] = "medium"
matplotlib.rcParams['axes.labelweight'] = 'medium'
matplotlib.rcParams['figure.titleweight'] = 'medium'
matplotlib.rcParams['axes.titleweight'] = 'medium'
matplotlib.rcParams['figure.figsize'] = 50, 5
sns.despine()


ax = sns.distplot(pbt_df_int1["coordinate"], color="gray", bins=100)
ax = sns.distplot(pbt_df_int2["coordinate"], color="black", bins=100)

ax.grid(False)
ax.set(ylabel='Density', xlabel="Coordinate from Alu start")
plt.title(f"Nr5a2 and Obox3 binding to SINE B1/Alu", y=1.01) 
#plt.xticks(rotation=90)
plt.xlim(-0.5,155)
sns.despine(top=True, right=True, left=False, bottom=False)

plt.savefig("./figures/Nr5a2_Obox_binding_to_Alu.pdf")
plt.show()
# Out:
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/2678977502.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(pbt_df_int1["coordinate"], color="gray", bins=100)
# /var/folders/fz/qb92b10d6d18gb2mcr1t_ls80000gq/T/ipykernel_24037/2678977502.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(pbt_df_int2["coordinate"], color="black", bins=100)

# %%
pbt_df_int = pbt_df_int.drop_duplicates()
rep_count = pbt_df_int.groupby(['blockCount']).size().reset_index(name='counts').sort_values("counts", ascending=False)
rep_count["counts_norm"] = rep_count["counts"]/df_closest.shape[0]*100

# %%
df_closest.to_csv(f"df_closest_{TF1n}_peak_{TF2n}_peak.bed", header=None, index=False)

# %%
rep_count = rep_count.replace("Alu", "SINE B1/Alu")

# %%
sns.set(font_scale=2, style="ticks")
sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
matplotlib.rcParams['font.weight'] = "medium"
matplotlib.rcParams['axes.labelweight'] = 'medium'
matplotlib.rcParams['figure.titleweight'] = 'medium'
matplotlib.rcParams['axes.titleweight'] = 'medium'
matplotlib.rcParams['figure.figsize'] = 10, 6

ax = sns.barplot(x="blockCount", y="counts_norm", data=rep_count, color="gray")
plt.xticks(rotation=90)

ax.set(xlabel='Repetitive element', ylabel=f'{TF1n}/{TF2n} peaks (%)')
plt.title(f"Percent of {TF1n}/{TF2n} peaks closer than 100 bp \n to repetitive elements (N={df_closest.shape[0]})")

out_pdf = f"./figures/{TF1n}_peak_{TF2n}_peak_by_rep_element.pdf"
plt.savefig(out_pdf)
plt.show()

# %%
print(f"Percentage of total peaks {TF1n}/{TF2n}:", df_closest.shape[0]/TF1.shape[0]*100, df_closest.shape[0]/TF2.shape[0]*100)
# Out:
# Percentage of total peaks Dux/Obox3: 2.8069004956157073 1.8337484433374844
